# %% [markdown]
# ### Variables which store numerical data

# %%
# Triangle values
base=12
height=7

# %%
area=(base*height)/2
area
# Out:
# 42.0

# %% [markdown]
# ### Arithmatic operations

# %%
# Consider values like below for all operations 
a=12
b=7

# %%
# Addition
a+b
# Out:
# 19

# %%
# Substraction
a-b
# Out:
# 5

# %%
# Multiplication
a*b
# Out:
# 84

# %%
# Devision
a/b
# Out:
# 1.7142857142857142

# %%
# Floor division
a//b
# Out:
# 1

# %%
# Reminder modules operation
a%b
# Out:
# 5

# %%
# Power to operation
a**3
# Out:
# 1728

# %% [markdown]
# ##### Scientific calculation

# %%
3.7e3
# Out:
# 3700.0

# %%
1e1
# Out:
# 10.0

# %%
2e1
# Out:
# 20.0

# %%
2.1e2
# Out:
# 210.0

# %%
3.2e-3
# Out:
# 0.0032

# %% [markdown]
# ### Order of operations

# %%
3*2+1
# Out:
# 7

# %%
4+4*9
# Out:
# 40

# %%
(4+4)*9
# Out:
# 72

# %% [markdown]
# ### type casting

# %%
a="12.3"

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# '12.3'

# %%
float(a)
# Out:
# 12.3

# %%
b=True

# %%
int(b)
# Out:
# 1

# %%
a=5
b=42
c=str(a)+str(b)
c
# Out:
# '542'

# %% [markdown]
# ### math package

# %%
import math

# %%
math.ceil(4.7)
# Out:
# 5

# %%
math.floor(7.8)
# Out:
# 7

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %% [markdown]
# ### Formating number

# %%
format(92,'b')
# Out:
# '1011100'

# %%
format(92,'o')
# Out:
# '134'
