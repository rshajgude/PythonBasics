# %% [markdown]
# ### there are 3 ways to use modules
#
# 1. Built in modules import those and use as it is
# 2. Third party modules install using pip and use them
# 3. User defined own modules, write it in same directory. import program without .py extention

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import mymodule
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import mymodule
#
# File ~/DataEngineering/02_Python/PythonBasics/PythonBasics/10_modules_n_pip/mymodule.py:5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "da9808bf-0eaa-4ec2-8bf0-17d0f6ffd86d",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "def bouble_it(n):\n",
#      11     "    return 2*n\n",
#      12     "\n",
#      13     "def triple_it(n):\n",
#      14     "    return 2*n\n",
#      15     "\n",
#      16     "def square_it(n):\n",
#      17     "    return 2*n\n",
#      18     "\n"
#      19    ]
#      20   }
#      21  ],
#      22  "metadata": {
#      23   "kernelspec": {
#      24    "display_name": "Python 3 (ipykernel)",
# ...
