# %%
def double_it(a,b):
    return 2*a, 2*b

# %%
double_it(3,6)
# Out:
# (6, 12)

# %%
l=double_it(88,23)

# %%
l[0]
# Out:
# 176

# %%
type(l)
# Out:
# tuple

# %%
num1, num2 = double_it(23,55)

# %%
num1
# Out:
# 46

# %%
num2
# Out:
# 110

# %%
# Tuple is a data structure which in ordered list of elements which immutable
l=(23,2,4,3,29)
l
# Out:
# (23, 2, 4, 3, 29)

# %%
l.append(88)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l.append(88)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
l[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(l)
# Out:
# 5

# %%
max(l)
# Out:
# 29

# %%
l+(12,23)
# Out:
# (23, 2, 4, 3, 29, 12, 23)

# %%
l*2
# Out:
# (23, 2, 4, 3, 29, 23, 2, 4, 3, 29)
