# %%
d={'Jan':45, 'Feb':39, 'Mar':41}

# %%
d
# Out:
# {'Jan': 45, 'Feb': 39, 'Mar': 41}

# %%
type(d)
# Out:
# dict

# %%
id(d)
# Out:
# 4439479232

# %%
# Key can be anything if key is a number then you can access directly as a number .
# if key is string must be accessed by enclosing in single quote
d={1:5, 'a':'test_value'}
d
# Out:
# {1: 5, 'a': 'test_value'}

# %%
d['1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d['1']
#
# KeyError: '1'

# %%
d['a']
# Out:
# 'test_value'

# %%
d={'Jan':45, 'Feb':39, 'Mar':41}

# %%
'Apr' in d
# Out:
# False

# %%
'Jan' in d
# Out:
# True

# %%
d.keys()
# Out:
# dict_keys(['Jan', 'Feb', 'Mar'])

# %%
type(d.values())
# Out:
# dict_values

# %%
dir(d)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
